# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/finetuning/evaluate/indommlu'
# !pip install -r requirements.txt
#model_path = "/content/drive/MyDrive/LLM"
# Out:
# /content/drive/MyDrive/finetuning/evaluate/indommlu
# ...
#   Cloning https://github.com/huggingface/peft.git to /tmp/pip-req-build-bvm7rw26
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /tmp/pip-req-build-bvm7rw26
#   Resolved https://github.com/huggingface/peft.git to commit 6d458b300fc2ed82e19f796b53af4c97d03ea604
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-mkmvr0te
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-mkmvr0te
#   Resolved https://github.com/huggingface/transformers.git to commit 05260a1fc1c8571a2b421ce72b680d5f1bc3e5a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install requests accelerate sentencepiece pytablewriter einops protobuf huggingface_hub==0.21.4
# !pip install -U transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.4/346.4 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 12.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.27.0
#     Uninstalling huggingface-hub-0.27.0:
#       Successfully uninstalled huggingface-hub-0.27.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.2.0 requires huggingface-hub>=0.23.0, but you have huggingface-hub 0.21.4 which is incompatible.
# diffusers 0.31.0 requires huggingface-hub>=0.23.2, but you have huggingface-hub 0.21.4 which is incompatible.
# gradio 5.9.1 requires huggingface-hub>=0.25.1, but you have huggingface-hub 0.21.4 which is incompatible.
# peft 0.14.1.dev0 requires huggingface_hub>=0.25.0, but you have huggingface-hub 0.21.4 which is incompatible.
# ...

# %%
# %cd '/content/drive/MyDrive/finetuning/evaluate/indommlu'
# !python evaluate2.py --by_letter --base_model='/content/drive/MyDrive/finetuning/LLM' --lora_weights='x' --output_folder="/content/drive/MyDrive/finetuning/benchmark"
# Out:
# /content/drive/MyDrive/finetuning/evaluate/indommlu
# 2024-12-23 11:14:53.849889: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-23 11:14:53.868985: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-23 11:14:53.874747: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-23 11:14:53.889147: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
